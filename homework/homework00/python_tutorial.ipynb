# %% [markdown]
# # FRE-GY 5040: Stage 00 pre-class setup
#
# **Student:** Paritosh Dwivedi

# %%
print("Hello, Bootcamp!")
# Out:
# Hello, Bootcamp!

# %% [markdown]
# ## Environment evidence
#
# This check records the Python runtime used to execute the notebook.

# %%
import sys

print(f"Python version: {sys.version.split()[0]}")
print(f"Interpreter path: {sys.executable}")
# Out:
# Python version: 3.14.3
# Interpreter path: /opt/homebrew/opt/python@3.14/bin/python3.14

# %% [markdown]
# ## Setup complete
#
# The Python virtual environment, Git, VS Code, and the cloned Bootcamp repository are set up for course work.
