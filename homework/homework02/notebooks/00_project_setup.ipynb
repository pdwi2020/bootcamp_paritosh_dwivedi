# %% [markdown]
# # Environment & Config Check
#
# Verify the Stage 02 environment, local configuration, and NumPy installation.

# %%
from pathlib import Path
import os

from dotenv import load_dotenv

# This notebook is one folder below the homework root, so it checks its parent.
# The root-level submission notebook starts in the homework root and needs no parent check.
current_dir = Path.cwd()
homework_root = current_dir.parent if current_dir.name == "notebooks" else current_dir
environment_loaded = load_dotenv(dotenv_path=homework_root / ".env", override=True)

print("Loaded .env:", environment_loaded)
print("API_KEY present:", bool(os.getenv("API_KEY")))
# Out:
# Loaded .env: True
# API_KEY present: True

# %%
import numpy as np

spy_daily_returns = np.array([0.004, -0.007, 0.011, 0.002, -0.003])
squared_returns = np.square(spy_daily_returns)

print("SPY daily returns:", spy_daily_returns)
print("Vectorized squared returns:", squared_returns)
# Out:
# SPY daily returns: [ 0.004 -0.007  0.011  0.002 -0.003]
# Vectorized squared returns: [1.60e-05 4.90e-05 1.21e-04 4.00e-06 9.00e-06]
